# %%
import requests

# %%
r = requests.get('https://api.github.com/events')
r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# [{'id': '34403243628',
#   'type': 'PushEvent',
#   'actor': {'id': 153940760,
#    'login': 'mdmaid69',
#    'display_login': 'mdmaid69',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mdmaid69',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153940760?'},
#   'repo': {'id': 732717980,
#    'name': 'mdmaid69/reimagined-giggle',
#    'url': 'https://api.github.com/repos/mdmaid69/reimagined-giggle'},
#   'payload': {'repository_id': 732717980,
#    'push_id': 16405292023,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6862718443c264dea1167d486f9f98862bc15be2',
#    'before': 'ac8bd9f4697274f36057d66815a8dfb262dc6526',
#    'commits': [{'sha': '6862718443c264dea1167d486f9f98862bc15be2',
#      'author': {'email': 'robot@alexsyw.me', 'name': 'mdmaid69'},
#      'message': 'film defend free contents month',
#      'distinct': True,
# ...
